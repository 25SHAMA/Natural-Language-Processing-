# %%
import re
from tqdm import tqdm
import numpy as np
import pandas as pd

with open('big.txt' , 'r') as fd:
    lines = fd.readlines()
    words = []
    for word in lines:
        words += re.findall('\w+' , word.lower())

# %%
words
# Out:
# ['the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  '15',
#  'in',
#  'our',
#  'series',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'copyright',
#  'laws',
#  'are',
#  'changing',
#  'all',
#  'over',
#  'the',
#  'world',
#  'be',
#  'sure',
#  'to',
#  'check',
#  'the',
#  'copyright',
#  'laws',
#  'for',
#  'your',
#  'country',
#  'before',
#  'downloading',
#  'or',
#  'redistributing',
#  'this',
#  'or',
#  'any',
#  'other',
#  'project',
#  'gutenberg',
#  'ebook',
#  'this',
#  'header',
#  'should',
#  'be',
#  'the',
#  'first',
#  'thing',
#  'seen',
#  'when',
#  'viewing',
#  'this',
#  'project',
#  'gutenberg',
#  'file',
#  'please',
#  'do',
#  'not',
#  'remove',
#  'it',
#  'do',
#  'not',
#  'change',
#  'or',
#  'edit',
#  'the',
#  'header',
#  'without',
#  'written',
#  'permission',
#  'please',
#  'read',
#  'the',
#  'legal',
#  'small',
#  'print',
#  'and',
#  'other',
#  'information',
#  'about',
#  'the',
#  'ebook',
#  'and',
#  'project',
#  'gutenberg',
#  'at',
#  'the',
#  'bottom',
#  'of',
#  'this',
#  'file',
#  'included',
#  'is',
#  'important',
#  'information',
#  'about',
#  'your',
#  'specific',
#  'rights',
#  'and',
#  'restrictions',
#  'in',
#  'how',
#  'the',
#  'file',
#  'may',
#  'be',
#  'used',
#  'you',
#  'can',
#  'also',
#  'find',
#  'out',
#  'about',
#  'how',
#  'to',
#  'make',
#  'a',
#  'donation',
#  'to',
#  'project',
#  'gutenberg',
#  'and',
#  'how',
#  'to',
#  'get',
#  'involved',
#  'welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'free',
#  'plain',
#  'vanilla',
#  'electronic',
#  'texts',
#  'ebooks',
#  'readable',
#  'by',
#  'both',
#  'humans',
#  'and',
#  'by',
#  'computers',
#  'since',
#  '1971',
#  'these',
#  'ebooks',
#  'were',
#  'prepared',
#  'by',
#  'thousands',
#  'of',
#  'volunteers',
#  'title',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'author',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'release',
#  'date',
#  'march',
#  '1999',
#  'ebook',
#  '1661',
#  'most',
#  'recently',
#  'updated',
#  'november',
#  '29',
#  '2002',
#  'edition',
#  '12',
#  'language',
#  'english',
#  'character',
#  'set',
#  'encoding',
#  'ascii',
#  'start',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'additional',
#  'editing',
#  'by',
#  'jose',
#  'menendez',
#  'the',
#  'adventures',
#  'of',
#  'sherlock',
#  'holmes',
#  'by',
#  'sir',
#  'arthur',
#  'conan',
#  'doyle',
#  'contents',
#  'i',
#  'a',
#  'scandal',
#  'in',
#  'bohemia',
#  'ii',
#  'the',
#  'red',
#  'headed',
#  'league',
#  'iii',
#  'a',
#  'case',
#  'of',
#  'identity',
#  'iv',
#  'the',
#  'boscombe',
#  'valley',
#  'mystery',
#  'v',
#  'the',
#  'five',
#  'orange',
#  'pips',
#  'vi',
#  'the',
#  'man',
#  'with',
#  'the',
#  'twisted',
#  'lip',
#  'vii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'blue',
#  'carbuncle',
#  'viii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'speckled',
#  'band',
#  'ix',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'engineer',
#  's',
#  'thumb',
#  'x',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'noble',
#  'bachelor',
#  'xi',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'beryl',
#  'coronet',
#  'xii',
#  'the',
#  'adventure',
#  'of',
#  'the',
#  'copper',
#  'beeches',
#  'adventure',
#  'i',
#  'a',
#  'scandal',
#  'in',
#  'bohemia',
#  'i',
#  'to',
#  'sherlock',
#  'holmes',
#  'she',
#  'is',
#  'always',
#  'the',
#  'woman',
#  'i',
#  'have',
#  'seldom',
#  'heard',
#  'him',
#  'mention',
#  'her',
#  'under',
#  'any',
#  'other',
#  'name',
#  'in',
#  'his',
#  'eyes',
#  'she',
#  'eclipses',
#  'and',
#  'predominates',
#  'the',
#  'whole',
#  'of',
#  'her',
#  'sex',
#  'it',
#  'was',
#  'not',
#  'that',
#  'he',
#  'felt',
#  'any',
#  'emotion',
#  'akin',
#  'to',
#  'love',
#  'for',
#  'irene',
#  'adler',
#  'all',
#  'emotions',
#  'and',
#  'that',
#  'one',
#  'particularly',
#  'were',
#  'abhorrent',
#  'to',
#  'his',
#  'cold',
#  'precise',
#  'but',
#  'admirably',
#  'balanced',
#  'mind',
#  'he',
#  'was',
#  'i',
#  'take',
#  'it',
#  'the',
#  'most',
#  'perfect',
#  'reasoning',
#  'and',
#  'observing',
#  'machine',
#  'that',
#  'the',
#  'world',
#  'has',
#  'seen',
#  'but',
#  'as',
#  'a',
#  'lover',
#  'he',
#  'would',
#  'have',
#  'placed',
#  'himself',
#  'in',
#  'a',
#  'false',
#  'position',
#  'he',
#  'never',
#  'spoke',
#  'of',
#  'the',
#  'softer',
#  'passions',
#  'save',
#  'with',
#  'a',
#  'gibe',
#  'and',
#  'a',
#  'sneer',
#  'they',
#  'were',
#  'admirable',
#  'things',
#  'for',
#  'the',
#  'observer',
#  'excellent',
#  'for',
#  'drawing',
#  'the',
#  'veil',
#  'from',
#  'men',
#  's',
#  'motives',
#  'and',
#  'actions',
#  'but',
#  'for',
#  'the',
#  'trained',
#  'reasoner',
#  'to',
#  'admit',
#  'such',
#  'intrusions',
#  'into',
#  'his',
#  'own',
#  'delicate',
#  'and',
#  'finely',
#  'adjusted',
#  'temperament',
#  'was',
#  'to',
#  'introduce',
#  'a',
#  'distracting',
#  'factor',
#  'which',
#  'might',
#  'throw',
#  'a',
#  'doubt',
#  'upon',
#  'all',
#  'his',
#  'mental',
#  'results',
#  'grit',
#  'in',
#  'a',
#  'sensitive',
#  'instrument',
#  'or',
#  'a',
#  'crack',
#  'in',
#  'one',
#  'of',
#  'his',
#  'own',
#  'high',
#  'power',
#  'lenses',
#  'would',
#  'not',
#  'be',
#  'more',
#  'disturbing',
#  'than',
#  'a',
#  'strong',
#  'emotion',
#  'in',
#  'a',
#  'nature',
#  'such',
#  'as',
#  'his',
#  'and',
#  'yet',
#  'there',
#  'was',
#  'but',
#  'one',
#  'woman',
#  'to',
#  'him',
#  'and',
#  'that',
#  'woman',
#  'was',
#  'the',
#  'late',
#  'irene',
#  'adler',
#  'of',
#  'dubious',
#  'and',
#  'questionable',
#  'memory',
#  'i',
#  'had',
#  'seen',
#  'little',
#  'of',
#  'holmes',
#  'lately',
#  'my',
#  'marriage',
#  'had',
#  'drifted',
#  'us',
#  'away',
#  'from',
#  'each',
#  'other',
#  'my',
#  'own',
#  'complete',
#  'happiness',
#  'and',
#  'the',
#  'home',
#  'centred',
#  'interests',
#  'which',
#  'rise',
#  'up',
#  'around',
#  'the',
#  'man',
#  'who',
#  'first',
#  'finds',
#  'himself',
#  'master',
#  'of',
#  'his',
#  'own',
#  'establishment',
#  'were',
#  'sufficient',
#  'to',
#  'absorb',
#  'all',
#  'my',
#  'attention',
#  'while',
#  'holmes',
#  'who',
#  'loathed',
#  'every',
#  'form',
#  'of',
#  'society',
#  'with',
#  'his',
#  'whole',
#  'bohemian',
#  'soul',
#  'remained',
#  'in',
#  'our',
#  'lodgings',
#  'in',
#  'baker',
#  'street',
#  'buried',
#  'among',
#  'his',
#  'old',
#  'books',
#  'and',
#  'alternating',
#  'from',
#  'week',
#  'to',
#  'week',
#  'between',
#  'cocaine',
#  'and',
#  'ambition',
#  'the',
#  'drowsiness',
#  'of',
#  'the',
#  'drug',
#  'and',
#  'the',
#  'fierce',
#  'energy',
#  'of',
#  'his',
#  'own',
#  'keen',
#  'nature',
#  'he',
#  'was',
#  'still',
#  'as',
#  'ever',
#  'deeply',
#  'attracted',
#  'by',
#  'the',
#  'study',
#  'of',
#  'crime',
#  'and',
#  'occupied',
#  'his',
#  'immense',
#  'faculties',
#  'and',
#  'extraordinary',
#  'powers',
#  'of',
#  'observation',
#  'in',
#  'following',
#  'out',
#  'those',
#  'clues',
#  'and',
#  'clearing',
#  'up',
#  'those',
#  'mysteries',
#  'which',
#  'had',
#  'been',
#  'abandoned',
#  'as',
#  'hopeless',
#  'by',
#  'the',
#  'official',
#  'police',
#  'from',
#  'time',
#  'to',
#  'time',
#  'i',
#  'heard',
#  'some',
#  'vague',
#  'account',
#  'of',
#  'his',
#  'doings',
#  'of',
#  'his',
#  'summons',
#  'to',
#  'odessa',
#  'in',
#  'the',
#  'case',
#  'of',
#  'the',
#  'trepoff',
#  'murder',
#  'of',
#  'his',
#  'clearing',
#  'up',
#  'of',
#  'the',
#  'singular',
#  'tragedy',
#  'of',
#  'the',
#  'atkinson',
#  'brothers',
#  'at',
#  'trincomalee',
#  'and',
#  'finally',
#  'of',
#  'the',
#  'mission',
#  'which',
#  'he',
#  'had',
#  'accomplished',
#  'so',
#  'delicately',
#  'and',
#  'successfully',
#  'for',
#  'the',
#  'reigning',
#  'family',
#  'of',
#  'holland',
#  'beyond',
#  'these',
#  'signs',
#  'of',
#  'his',
#  'activity',
#  'however',
#  'which',
#  'i',
#  'merely',
#  'shared',
#  'with',
#  'all',
#  'the',
#  'readers',
#  'of',
#  'the',
#  'daily',
#  'press',
#  'i',
#  'knew',
#  'little',
#  'of',
#  'my',
#  'former',
#  'friend',
#  'and',
#  'companion',
#  'one',
#  'night',
#  'it',
#  'was',
#  'on',
#  'the',
#  'twentieth',
#  'of',
#  'march',
#  '1888',
#  'i',
#  'was',
#  'returning',
#  'from',
#  'a',
#  'journey',
#  'to',
#  'a',
#  'patient',
#  'for',
#  'i',
#  'had',
#  'now',
#  'returned',
#  'to',
#  'civil',
#  'practice',
#  'when',
#  'my',
#  'way',
#  'led',
#  'me',
#  'through',
#  'baker',
#  'street',
#  'as',
#  'i',
#  'passed',
#  'the',
#  'well',
#  'remembered',
#  'door',
#  'which',
#  'must',
#  'always',
#  'be',
#  'associated',
#  'in',
#  'my',
#  'mind',
#  'with',
#  'my',
#  'wooing',
#  'and',
#  'with',
#  'the',
#  'dark',
#  'incidents',
#  'of',
#  'the',
#  'study',
#  'in',
#  'scarlet',
#  'i',
#  'was',
#  'seized',
#  'with',
#  'a',
#  'keen',
#  'desire',
#  'to',
#  'see',
#  'holmes',
#  'again',
#  'and',
#  'to',
#  'know',
#  'how',
#  'he',
#  'was',
#  'employing',
#  'his',
#  'extraordinary',
#  'powers',
#  'his',
#  'rooms',
#  'were',
#  'brilliantly',
#  'lit',
#  'and',
#  'even',
#  'as',
#  'i',
#  'looked',
#  'up',
#  'i',
#  'saw',
#  'his',
#  'tall',
#  'spare',
#  'figure',
#  'pass',
#  'twice',
#  'in',
#  'a',
#  'dark',
#  'silhouette',
#  'against',
#  'the',
#  'blind',
#  'he',
#  'was',
#  'pacing',
#  'the',
#  'room',
#  'swiftly',
#  'eagerly',
#  'with',
#  'his',
#  'head',
#  'sunk',
#  'upon',
#  'his',
#  'chest',
#  'and',
#  'his',
#  'hands',
#  'clasped',
#  'behind',
#  'him',
#  'to',
#  'me',
#  'who',
#  'knew',
#  'his',
#  'every',
#  'mood',
#  'and',
#  'habit',
#  'his',
#  'attitude',
#  'and',
#  'manner',
#  'told',
#  'their',
#  'own',
#  'story',
#  'he',
#  'was',
#  'at',
#  'work',
#  'again',
#  'he',
#  'had',
#  'risen',
#  'out',
#  'of',
#  'his',
#  'drug',
#  'created',
#  'dreams',
#  'and',
#  'was',
#  'hot',
#  'upon',
#  'the',
#  'scent',
#  'of',
#  'some',
#  'new',
#  'problem',
#  'i',
#  'rang',
#  'the',
#  'bell',
#  'and',
#  'was',
#  'shown',
#  'up',
#  'to',
#  'the',
#  'chamber',
#  'which',
#  'had',
#  'formerly',
#  'been',
#  'in',
#  'part',
#  'my',
#  'own',
#  'his',
#  'manner',
#  'was',
#  'not',
#  'effusive',
#  'it',
#  'seldom',
#  'was',
#  'but',
#  'he',
#  'was',
#  'glad',
#  'i',
#  'think',
#  'to',
#  'see',
#  'me',
#  'with',
#  'hardly',
#  'a',
#  'word',
#  'spoken',
#  'but',
#  'with',
#  'a',
#  'kindly',
#  'eye',
#  'he',
#  'waved',
#  'me',
#  'to',
#  'an',
#  'armchair',
#  'threw',
#  'across',
#  'his',
#  'case',
#  'of',
#  'cigars',
#  'and',
#  'indicated',
#  'a',
#  'spirit',
#  'case',
#  'and',
#  'a',
#  'gasogene',
#  'in',
#  'the',
#  'corner',
#  'then',
#  'he',
#  'stood',
#  'before',
#  'the',
#  'fire',
#  'and',
#  'looked',
#  'me',
#  'over',
#  'in',
#  'his',
#  'singular',
#  'introspective',
#  'fashion',
#  'wedlock',
#  'suits',
#  'you',
#  'he',
#  'remarked',
#  'i',
#  ...]

# %% [markdown]
# # Getting the Pairs

# %%
def get_pairs(words, n):
    
    data = []
    for i in range(len(words) - n):
        data.append(' '.join(words[i:i+n]))
    return data

# %%
get_pairs(words , 5)
# Out:
# ['the project gutenberg ebook of',
#  'project gutenberg ebook of the',
#  'gutenberg ebook of the adventures',
#  'ebook of the adventures of',
#  'of the adventures of sherlock',
#  'the adventures of sherlock holmes',
#  'adventures of sherlock holmes by',
#  'of sherlock holmes by sir',
#  'sherlock holmes by sir arthur',
#  'holmes by sir arthur conan',
#  'by sir arthur conan doyle',
#  'sir arthur conan doyle 15',
#  'arthur conan doyle 15 in',
#  'conan doyle 15 in our',
#  'doyle 15 in our series',
#  '15 in our series by',
#  'in our series by sir',
#  'our series by sir arthur',
#  'series by sir arthur conan',
#  'by sir arthur conan doyle',
#  'sir arthur conan doyle copyright',
#  'arthur conan doyle copyright laws',
#  'conan doyle copyright laws are',
#  'doyle copyright laws are changing',
#  'copyright laws are changing all',
#  'laws are changing all over',
#  'are changing all over the',
#  'changing all over the world',
#  'all over the world be',
#  'over the world be sure',
#  'the world be sure to',
#  'world be sure to check',
#  'be sure to check the',
#  'sure to check the copyright',
#  'to check the copyright laws',
#  'check the copyright laws for',
#  'the copyright laws for your',
#  'copyright laws for your country',
#  'laws for your country before',
#  'for your country before downloading',
#  'your country before downloading or',
#  'country before downloading or redistributing',
#  'before downloading or redistributing this',
#  'downloading or redistributing this or',
#  'or redistributing this or any',
#  'redistributing this or any other',
#  'this or any other project',
#  'or any other project gutenberg',
#  'any other project gutenberg ebook',
#  'other project gutenberg ebook this',
#  'project gutenberg ebook this header',
#  'gutenberg ebook this header should',
#  'ebook this header should be',
#  'this header should be the',
#  'header should be the first',
#  'should be the first thing',
#  'be the first thing seen',
#  'the first thing seen when',
#  'first thing seen when viewing',
#  'thing seen when viewing this',
#  'seen when viewing this project',
#  'when viewing this project gutenberg',
#  'viewing this project gutenberg file',
#  'this project gutenberg file please',
#  'project gutenberg file please do',
#  'gutenberg file please do not',
#  'file please do not remove',
#  'please do not remove it',
#  'do not remove it do',
#  'not remove it do not',
#  'remove it do not change',
#  'it do not change or',
#  'do not change or edit',
#  'not change or edit the',
#  'change or edit the header',
#  'or edit the header without',
#  'edit the header without written',
#  'the header without written permission',
#  'header without written permission please',
#  'without written permission please read',
#  'written permission please read the',
#  'permission please read the legal',
#  'please read the legal small',
#  'read the legal small print',
#  'the legal small print and',
#  'legal small print and other',
#  'small print and other information',
#  'print and other information about',
#  'and other information about the',
#  'other information about the ebook',
#  'information about the ebook and',
#  'about the ebook and project',
#  'the ebook and project gutenberg',
#  'ebook and project gutenberg at',
#  'and project gutenberg at the',
#  'project gutenberg at the bottom',
#  'gutenberg at the bottom of',
#  'at the bottom of this',
#  'the bottom of this file',
#  'bottom of this file included',
#  'of this file included is',
#  'this file included is important',
#  'file included is important information',
#  'included is important information about',
#  'is important information about your',
#  'important information about your specific',
#  'information about your specific rights',
#  'about your specific rights and',
#  'your specific rights and restrictions',
#  'specific rights and restrictions in',
#  'rights and restrictions in how',
#  'and restrictions in how the',
#  'restrictions in how the file',
#  'in how the file may',
#  'how the file may be',
#  'the file may be used',
#  'file may be used you',
#  'may be used you can',
#  'be used you can also',
#  'used you can also find',
#  'you can also find out',
#  'can also find out about',
#  'also find out about how',
#  'find out about how to',
#  'out about how to make',
#  'about how to make a',
#  'how to make a donation',
#  'to make a donation to',
#  'make a donation to project',
#  'a donation to project gutenberg',
#  'donation to project gutenberg and',
#  'to project gutenberg and how',
#  'project gutenberg and how to',
#  'gutenberg and how to get',
#  'and how to get involved',
#  'how to get involved welcome',
#  'to get involved welcome to',
#  'get involved welcome to the',
#  'involved welcome to the world',
#  'welcome to the world of',
#  'to the world of free',
#  'the world of free plain',
#  'world of free plain vanilla',
#  'of free plain vanilla electronic',
#  'free plain vanilla electronic texts',
#  'plain vanilla electronic texts ebooks',
#  'vanilla electronic texts ebooks readable',
#  'electronic texts ebooks readable by',
#  'texts ebooks readable by both',
#  'ebooks readable by both humans',
#  'readable by both humans and',
#  'by both humans and by',
#  'both humans and by computers',
#  'humans and by computers since',
#  'and by computers since 1971',
#  'by computers since 1971 these',
#  'computers since 1971 these ebooks',
#  'since 1971 these ebooks were',
#  '1971 these ebooks were prepared',
#  'these ebooks were prepared by',
#  'ebooks were prepared by thousands',
#  'were prepared by thousands of',
#  'prepared by thousands of volunteers',
#  'by thousands of volunteers title',
#  'thousands of volunteers title the',
#  'of volunteers title the adventures',
#  'volunteers title the adventures of',
#  'title the adventures of sherlock',
#  'the adventures of sherlock holmes',
#  'adventures of sherlock holmes author',
#  'of sherlock holmes author sir',
#  'sherlock holmes author sir arthur',
#  'holmes author sir arthur conan',
#  'author sir arthur conan doyle',
#  'sir arthur conan doyle release',
#  'arthur conan doyle release date',
#  'conan doyle release date march',
#  'doyle release date march 1999',
#  'release date march 1999 ebook',
#  'date march 1999 ebook 1661',
#  'march 1999 ebook 1661 most',
#  '1999 ebook 1661 most recently',
#  'ebook 1661 most recently updated',
#  '1661 most recently updated november',
#  'most recently updated november 29',
#  'recently updated november 29 2002',
#  'updated november 29 2002 edition',
#  'november 29 2002 edition 12',
#  '29 2002 edition 12 language',
#  '2002 edition 12 language english',
#  'edition 12 language english character',
#  '12 language english character set',
#  'language english character set encoding',
#  'english character set encoding ascii',
#  'character set encoding ascii start',
#  'set encoding ascii start of',
#  'encoding ascii start of the',
#  'ascii start of the project',
#  'start of the project gutenberg',
#  'of the project gutenberg ebook',
#  'the project gutenberg ebook the',
#  'project gutenberg ebook the adventures',
#  'gutenberg ebook the adventures of',
#  'ebook the adventures of sherlock',
#  'the adventures of sherlock holmes',
#  'adventures of sherlock holmes additional',
#  'of sherlock holmes additional editing',
#  'sherlock holmes additional editing by',
#  'holmes additional editing by jose',
#  'additional editing by jose menendez',
#  'editing by jose menendez the',
#  'by jose menendez the adventures',
#  'jose menendez the adventures of',
#  'menendez the adventures of sherlock',
#  'the adventures of sherlock holmes',
#  'adventures of sherlock holmes by',
#  'of sherlock holmes by sir',
#  'sherlock holmes by sir arthur',
#  'holmes by sir arthur conan',
#  'by sir arthur conan doyle',
#  'sir arthur conan doyle contents',
#  'arthur conan doyle contents i',
#  'conan doyle contents i a',
#  'doyle contents i a scandal',
#  'contents i a scandal in',
#  'i a scandal in bohemia',
#  'a scandal in bohemia ii',
#  'scandal in bohemia ii the',
#  'in bohemia ii the red',
#  'bohemia ii the red headed',
#  'ii the red headed league',
#  'the red headed league iii',
#  'red headed league iii a',
#  'headed league iii a case',
#  'league iii a case of',
#  'iii a case of identity',
#  'a case of identity iv',
#  'case of identity iv the',
#  'of identity iv the boscombe',
#  'identity iv the boscombe valley',
#  'iv the boscombe valley mystery',
#  'the boscombe valley mystery v',
#  'boscombe valley mystery v the',
#  'valley mystery v the five',
#  'mystery v the five orange',
#  'v the five orange pips',
#  'the five orange pips vi',
#  'five orange pips vi the',
#  'orange pips vi the man',
#  'pips vi the man with',
#  'vi the man with the',
#  'the man with the twisted',
#  'man with the twisted lip',
#  'with the twisted lip vii',
#  'the twisted lip vii the',
#  'twisted lip vii the adventure',
#  'lip vii the adventure of',
#  'vii the adventure of the',
#  'the adventure of the blue',
#  'adventure of the blue carbuncle',
#  'of the blue carbuncle viii',
#  'the blue carbuncle viii the',
#  'blue carbuncle viii the adventure',
#  'carbuncle viii the adventure of',
#  'viii the adventure of the',
#  'the adventure of the speckled',
#  'adventure of the speckled band',
#  'of the speckled band ix',
#  'the speckled band ix the',
#  'speckled band ix the adventure',
#  'band ix the adventure of',
#  'ix the adventure of the',
#  'the adventure of the engineer',
#  'adventure of the engineer s',
#  'of the engineer s thumb',
#  'the engineer s thumb x',
#  'engineer s thumb x the',
#  's thumb x the adventure',
#  'thumb x the adventure of',
#  'x the adventure of the',
#  'the adventure of the noble',
#  'adventure of the noble bachelor',
#  'of the noble bachelor xi',
#  'the noble bachelor xi the',
#  'noble bachelor xi the adventure',
#  'bachelor xi the adventure of',
#  'xi the adventure of the',
#  'the adventure of the beryl',
#  'adventure of the beryl coronet',
#  'of the beryl coronet xii',
#  'the beryl coronet xii the',
#  'beryl coronet xii the adventure',
#  'coronet xii the adventure of',
#  'xii the adventure of the',
#  'the adventure of the copper',
#  'adventure of the copper beeches',
#  'of the copper beeches adventure',
#  'the copper beeches adventure i',
#  'copper beeches adventure i a',
#  'beeches adventure i a scandal',
#  'adventure i a scandal in',
#  'i a scandal in bohemia',
#  'a scandal in bohemia i',
#  'scandal in bohemia i to',
#  'in bohemia i to sherlock',
#  'bohemia i to sherlock holmes',
#  'i to sherlock holmes she',
#  'to sherlock holmes she is',
#  'sherlock holmes she is always',
#  'holmes she is always the',
#  'she is always the woman',
#  'is always the woman i',
#  'always the woman i have',
#  'the woman i have seldom',
#  'woman i have seldom heard',
#  'i have seldom heard him',
#  'have seldom heard him mention',
#  'seldom heard him mention her',
#  'heard him mention her under',
#  'him mention her under any',
#  'mention her under any other',
#  'her under any other name',
#  'under any other name in',
#  'any other name in his',
#  'other name in his eyes',
#  'name in his eyes she',
#  'in his eyes she eclipses',
#  'his eyes she eclipses and',
#  'eyes she eclipses and predominates',
#  'she eclipses and predominates the',
#  'eclipses and predominates the whole',
#  'and predominates the whole of',
#  'predominates the whole of her',
#  'the whole of her sex',
#  'whole of her sex it',
#  'of her sex it was',
#  'her sex it was not',
#  'sex it was not that',
#  'it was not that he',
#  'was not that he felt',
#  'not that he felt any',
#  'that he felt any emotion',
#  'he felt any emotion akin',
#  'felt any emotion akin to',
#  'any emotion akin to love',
#  'emotion akin to love for',
#  'akin to love for irene',
#  'to love for irene adler',
#  'love for irene adler all',
#  'for irene adler all emotions',
#  'irene adler all emotions and',
#  'adler all emotions and that',
#  'all emotions and that one',
#  'emotions and that one particularly',
#  'and that one particularly were',
#  'that one particularly were abhorrent',
#  'one particularly were abhorrent to',
#  'particularly were abhorrent to his',
#  'were abhorrent to his cold',
#  'abhorrent to his cold precise',
#  'to his cold precise but',
#  'his cold precise but admirably',
#  'cold precise but admirably balanced',
#  'precise but admirably balanced mind',
#  'but admirably balanced mind he',
#  'admirably balanced mind he was',
#  'balanced mind he was i',
#  'mind he was i take',
#  'he was i take it',
#  'was i take it the',
#  'i take it the most',
#  'take it the most perfect',
#  'it the most perfect reasoning',
#  'the most perfect reasoning and',
#  'most perfect reasoning and observing',
#  'perfect reasoning and observing machine',
#  'reasoning and observing machine that',
#  'and observing machine that the',
#  'observing machine that the world',
#  'machine that the world has',
#  'that the world has seen',
#  'the world has seen but',
#  'world has seen but as',
#  'has seen but as a',
#  'seen but as a lover',
#  'but as a lover he',
#  'as a lover he would',
#  'a lover he would have',
#  'lover he would have placed',
#  'he would have placed himself',
#  'would have placed himself in',
#  'have placed himself in a',
#  'placed himself in a false',
#  'himself in a false position',
#  'in a false position he',
#  'a false position he never',
#  'false position he never spoke',
#  'position he never spoke of',
#  'he never spoke of the',
#  'never spoke of the softer',
#  'spoke of the softer passions',
#  'of the softer passions save',
#  'the softer passions save with',
#  'softer passions save with a',
#  'passions save with a gibe',
#  'save with a gibe and',
#  'with a gibe and a',
#  'a gibe and a sneer',
#  'gibe and a sneer they',
#  'and a sneer they were',
#  'a sneer they were admirable',
#  'sneer they were admirable things',
#  'they were admirable things for',
#  'were admirable things for the',
#  'admirable things for the observer',
#  'things for the observer excellent',
#  'for the observer excellent for',
#  'the observer excellent for drawing',
#  'observer excellent for drawing the',
#  'excellent for drawing the veil',
#  'for drawing the veil from',
#  'drawing the veil from men',
#  'the veil from men s',
#  'veil from men s motives',
#  'from men s motives and',
#  'men s motives and actions',
#  's motives and actions but',
#  'motives and actions but for',
#  'and actions but for the',
#  'actions but for the trained',
#  'but for the trained reasoner',
#  'for the trained reasoner to',
#  'the trained reasoner to admit',
#  'trained reasoner to admit such',
#  'reasoner to admit such intrusions',
#  'to admit such intrusions into',
#  'admit such intrusions into his',
#  'such intrusions into his own',
#  'intrusions into his own delicate',
#  'into his own delicate and',
#  'his own delicate and finely',
#  'own delicate and finely adjusted',
#  'delicate and finely adjusted temperament',
#  'and finely adjusted temperament was',
#  'finely adjusted temperament was to',
#  'adjusted temperament was to introduce',
#  'temperament was to introduce a',
#  'was to introduce a distracting',
#  'to introduce a distracting factor',
#  'introduce a distracting factor which',
#  'a distracting factor which might',
#  'distracting factor which might throw',
#  'factor which might throw a',
#  'which might throw a doubt',
#  'might throw a doubt upon',
#  'throw a doubt upon all',
#  'a doubt upon all his',
#  'doubt upon all his mental',
#  'upon all his mental results',
#  'all his mental results grit',
#  'his mental results grit in',
#  'mental results grit in a',
#  'results grit in a sensitive',
#  'grit in a sensitive instrument',
#  'in a sensitive instrument or',
#  'a sensitive instrument or a',
#  'sensitive instrument or a crack',
#  'instrument or a crack in',
#  'or a crack in one',
#  'a crack in one of',
#  'crack in one of his',
#  'in one of his own',
#  'one of his own high',
#  'of his own high power',
#  'his own high power lenses',
#  'own high power lenses would',
#  'high power lenses would not',
#  'power lenses would not be',
#  'lenses would not be more',
#  'would not be more disturbing',
#  'not be more disturbing than',
#  'be more disturbing than a',
#  'more disturbing than a strong',
#  'disturbing than a strong emotion',
#  'than a strong emotion in',
#  'a strong emotion in a',
#  'strong emotion in a nature',
#  'emotion in a nature such',
#  'in a nature such as',
#  'a nature such as his',
#  'nature such as his and',
#  'such as his and yet',
#  'as his and yet there',
#  'his and yet there was',
#  'and yet there was but',
#  'yet there was but one',
#  'there was but one woman',
#  'was but one woman to',
#  'but one woman to him',
#  'one woman to him and',
#  'woman to him and that',
#  'to him and that woman',
#  'him and that woman was',
#  'and that woman was the',
#  'that woman was the late',
#  'woman was the late irene',
#  'was the late irene adler',
#  'the late irene adler of',
#  'late irene adler of dubious',
#  'irene adler of dubious and',
#  'adler of dubious and questionable',
#  'of dubious and questionable memory',
#  'dubious and questionable memory i',
#  'and questionable memory i had',
#  'questionable memory i had seen',
#  'memory i had seen little',
#  'i had seen little of',
#  'had seen little of holmes',
#  'seen little of holmes lately',
#  'little of holmes lately my',
#  'of holmes lately my marriage',
#  'holmes lately my marriage had',
#  'lately my marriage had drifted',
#  'my marriage had drifted us',
#  'marriage had drifted us away',
#  'had drifted us away from',
#  'drifted us away from each',
#  'us away from each other',
#  'away from each other my',
#  'from each other my own',
#  'each other my own complete',
#  'other my own complete happiness',
#  'my own complete happiness and',
#  'own complete happiness and the',
#  'complete happiness and the home',
#  'happiness and the home centred',
#  'and the home centred interests',
#  'the home centred interests which',
#  'home centred interests which rise',
#  'centred interests which rise up',
#  'interests which rise up around',
#  'which rise up around the',
#  'rise up around the man',
#  'up around the man who',
#  'around the man who first',
#  'the man who first finds',
#  'man who first finds himself',
#  'who first finds himself master',
#  'first finds himself master of',
#  'finds himself master of his',
#  'himself master of his own',
#  'master of his own establishment',
#  'of his own establishment were',
#  'his own establishment were sufficient',
#  'own establishment were sufficient to',
#  'establishment were sufficient to absorb',
#  'were sufficient to absorb all',
#  'sufficient to absorb all my',
#  'to absorb all my attention',
#  'absorb all my attention while',
#  'all my attention while holmes',
#  'my attention while holmes who',
#  'attention while holmes who loathed',
#  'while holmes who loathed every',
#  'holmes who loathed every form',
#  'who loathed every form of',
#  'loathed every form of society',
#  'every form of society with',
#  'form of society with his',
#  'of society with his whole',
#  'society with his whole bohemian',
#  'with his whole bohemian soul',
#  'his whole bohemian soul remained',
#  'whole bohemian soul remained in',
#  'bohemian soul remained in our',
#  'soul remained in our lodgings',
#  'remained in our lodgings in',
#  'in our lodgings in baker',
#  'our lodgings in baker street',
#  'lodgings in baker street buried',
#  'in baker street buried among',
#  'baker street buried among his',
#  'street buried among his old',
#  'buried among his old books',
#  'among his old books and',
#  'his old books and alternating',
#  'old books and alternating from',
#  'books and alternating from week',
#  'and alternating from week to',
#  'alternating from week to week',
#  'from week to week between',
#  'week to week between cocaine',
#  'to week between cocaine and',
#  'week between cocaine and ambition',
#  'between cocaine and ambition the',
#  'cocaine and ambition the drowsiness',
#  'and ambition the drowsiness of',
#  'ambition the drowsiness of the',
#  'the drowsiness of the drug',
#  'drowsiness of the drug and',
#  'of the drug and the',
#  'the drug and the fierce',
#  'drug and the fierce energy',
#  'and the fierce energy of',
#  'the fierce energy of his',
#  'fierce energy of his own',
#  'energy of his own keen',
#  'of his own keen nature',
#  'his own keen nature he',
#  'own keen nature he was',
#  'keen nature he was still',
#  'nature he was still as',
#  'he was still as ever',
#  'was still as ever deeply',
#  'still as ever deeply attracted',
#  'as ever deeply attracted by',
#  'ever deeply attracted by the',
#  'deeply attracted by the study',
#  'attracted by the study of',
#  'by the study of crime',
#  'the study of crime and',
#  'study of crime and occupied',
#  'of crime and occupied his',
#  'crime and occupied his immense',
#  'and occupied his immense faculties',
#  'occupied his immense faculties and',
#  'his immense faculties and extraordinary',
#  'immense faculties and extraordinary powers',
#  'faculties and extraordinary powers of',
#  'and extraordinary powers of observation',
#  'extraordinary powers of observation in',
#  'powers of observation in following',
#  'of observation in following out',
#  'observation in following out those',
#  'in following out those clues',
#  'following out those clues and',
#  'out those clues and clearing',
#  'those clues and clearing up',
#  'clues and clearing up those',
#  'and clearing up those mysteries',
#  'clearing up those mysteries which',
#  'up those mysteries which had',
#  'those mysteries which had been',
#  'mysteries which had been abandoned',
#  'which had been abandoned as',
#  'had been abandoned as hopeless',
#  'been abandoned as hopeless by',
#  'abandoned as hopeless by the',
#  'as hopeless by the official',
#  'hopeless by the official police',
#  'by the official police from',
#  'the official police from time',
#  'official police from time to',
#  'police from time to time',
#  'from time to time i',
#  'time to time i heard',
#  'to time i heard some',
#  'time i heard some vague',
#  'i heard some vague account',
#  'heard some vague account of',
#  'some vague account of his',
#  'vague account of his doings',
#  'account of his doings of',
#  'of his doings of his',
#  'his doings of his summons',
#  'doings of his summons to',
#  'of his summons to odessa',
#  'his summons to odessa in',
#  'summons to odessa in the',
#  'to odessa in the case',
#  'odessa in the case of',
#  'in the case of the',
#  'the case of the trepoff',
#  'case of the trepoff murder',
#  'of the trepoff murder of',
#  'the trepoff murder of his',
#  'trepoff murder of his clearing',
#  'murder of his clearing up',
#  'of his clearing up of',
#  'his clearing up of the',
#  'clearing up of the singular',
#  'up of the singular tragedy',
#  'of the singular tragedy of',
#  'the singular tragedy of the',
#  'singular tragedy of the atkinson',
#  'tragedy of the atkinson brothers',
#  'of the atkinson brothers at',
#  'the atkinson brothers at trincomalee',
#  'atkinson brothers at trincomalee and',
#  'brothers at trincomalee and finally',
#  'at trincomalee and finally of',
#  'trincomalee and finally of the',
#  'and finally of the mission',
#  'finally of the mission which',
#  'of the mission which he',
#  'the mission which he had',
#  'mission which he had accomplished',
#  'which he had accomplished so',
#  'he had accomplished so delicately',
#  'had accomplished so delicately and',
#  'accomplished so delicately and successfully',
#  'so delicately and successfully for',
#  'delicately and successfully for the',
#  'and successfully for the reigning',
#  'successfully for the reigning family',
#  'for the reigning family of',
#  'the reigning family of holland',
#  'reigning family of holland beyond',
#  'family of holland beyond these',
#  'of holland beyond these signs',
#  'holland beyond these signs of',
#  'beyond these signs of his',
#  'these signs of his activity',
#  'signs of his activity however',
#  'of his activity however which',
#  'his activity however which i',
#  'activity however which i merely',
#  'however which i merely shared',
#  'which i merely shared with',
#  'i merely shared with all',
#  'merely shared with all the',
#  'shared with all the readers',
#  'with all the readers of',
#  'all the readers of the',
#  'the readers of the daily',
#  'readers of the daily press',
#  'of the daily press i',
#  'the daily press i knew',
#  'daily press i knew little',
#  'press i knew little of',
#  'i knew little of my',
#  'knew little of my former',
#  'little of my former friend',
#  'of my former friend and',
#  'my former friend and companion',
#  'former friend and companion one',
#  'friend and companion one night',
#  'and companion one night it',
#  'companion one night it was',
#  'one night it was on',
#  'night it was on the',
#  'it was on the twentieth',
#  'was on the twentieth of',
#  'on the twentieth of march',
#  'the twentieth of march 1888',
#  'twentieth of march 1888 i',
#  'of march 1888 i was',
#  'march 1888 i was returning',
#  '1888 i was returning from',
#  'i was returning from a',
#  'was returning from a journey',
#  'returning from a journey to',
#  'from a journey to a',
#  'a journey to a patient',
#  'journey to a patient for',
#  'to a patient for i',
#  'a patient for i had',
#  'patient for i had now',
#  'for i had now returned',
#  'i had now returned to',
#  'had now returned to civil',
#  'now returned to civil practice',
#  'returned to civil practice when',
#  'to civil practice when my',
#  'civil practice when my way',
#  'practice when my way led',
#  'when my way led me',
#  'my way led me through',
#  'way led me through baker',
#  'led me through baker street',
#  'me through baker street as',
#  'through baker street as i',
#  'baker street as i passed',
#  'street as i passed the',
#  'as i passed the well',
#  'i passed the well remembered',
#  'passed the well remembered door',
#  'the well remembered door which',
#  'well remembered door which must',
#  'remembered door which must always',
#  'door which must always be',
#  'which must always be associated',
#  'must always be associated in',
#  'always be associated in my',
#  'be associated in my mind',
#  'associated in my mind with',
#  'in my mind with my',
#  'my mind with my wooing',
#  'mind with my wooing and',
#  'with my wooing and with',
#  'my wooing and with the',
#  'wooing and with the dark',
#  'and with the dark incidents',
#  'with the dark incidents of',
#  'the dark incidents of the',
#  'dark incidents of the study',
#  'incidents of the study in',
#  'of the study in scarlet',
#  'the study in scarlet i',
#  'study in scarlet i was',
#  'in scarlet i was seized',
#  'scarlet i was seized with',
#  'i was seized with a',
#  'was seized with a keen',
#  'seized with a keen desire',
#  'with a keen desire to',
#  'a keen desire to see',
#  'keen desire to see holmes',
#  'desire to see holmes again',
#  'to see holmes again and',
#  'see holmes again and to',
#  'holmes again and to know',
#  'again and to know how',
#  'and to know how he',
#  'to know how he was',
#  'know how he was employing',
#  'how he was employing his',
#  'he was employing his extraordinary',
#  'was employing his extraordinary powers',
#  'employing his extraordinary powers his',
#  'his extraordinary powers his rooms',
#  'extraordinary powers his rooms were',
#  'powers his rooms were brilliantly',
#  'his rooms were brilliantly lit',
#  'rooms were brilliantly lit and',
#  'were brilliantly lit and even',
#  'brilliantly lit and even as',
#  'lit and even as i',
#  'and even as i looked',
#  'even as i looked up',
#  'as i looked up i',
#  'i looked up i saw',
#  'looked up i saw his',
#  'up i saw his tall',
#  'i saw his tall spare',
#  'saw his tall spare figure',
#  'his tall spare figure pass',
#  'tall spare figure pass twice',
#  'spare figure pass twice in',
#  'figure pass twice in a',
#  'pass twice in a dark',
#  'twice in a dark silhouette',
#  'in a dark silhouette against',
#  'a dark silhouette against the',
#  'dark silhouette against the blind',
#  'silhouette against the blind he',
#  'against the blind he was',
#  'the blind he was pacing',
#  'blind he was pacing the',
#  'he was pacing the room',
#  'was pacing the room swiftly',
#  'pacing the room swiftly eagerly',
#  'the room swiftly eagerly with',
#  'room swiftly eagerly with his',
#  'swiftly eagerly with his head',
#  'eagerly with his head sunk',
#  'with his head sunk upon',
#  'his head sunk upon his',
#  'head sunk upon his chest',
#  'sunk upon his chest and',
#  'upon his chest and his',
#  'his chest and his hands',
#  'chest and his hands clasped',
#  'and his hands clasped behind',
#  'his hands clasped behind him',
#  'hands clasped behind him to',
#  'clasped behind him to me',
#  'behind him to me who',
#  'him to me who knew',
#  'to me who knew his',
#  'me who knew his every',
#  'who knew his every mood',
#  'knew his every mood and',
#  'his every mood and habit',
#  'every mood and habit his',
#  'mood and habit his attitude',
#  'and habit his attitude and',
#  'habit his attitude and manner',
#  'his attitude and manner told',
#  'attitude and manner told their',
#  'and manner told their own',
#  'manner told their own story',
#  'told their own story he',
#  'their own story he was',
#  'own story he was at',
#  'story he was at work',
#  'he was at work again',
#  'was at work again he',
#  'at work again he had',
#  'work again he had risen',
#  'again he had risen out',
#  'he had risen out of',
#  'had risen out of his',
#  'risen out of his drug',
#  'out of his drug created',
#  'of his drug created dreams',
#  'his drug created dreams and',
#  'drug created dreams and was',
#  'created dreams and was hot',
#  'dreams and was hot upon',
#  'and was hot upon the',
#  'was hot upon the scent',
#  'hot upon the scent of',
#  'upon the scent of some',
#  'the scent of some new',
#  'scent of some new problem',
#  'of some new problem i',
#  'some new problem i rang',
#  'new problem i rang the',
#  'problem i rang the bell',
#  'i rang the bell and',
#  'rang the bell and was',
#  'the bell and was shown',
#  'bell and was shown up',
#  'and was shown up to',
#  'was shown up to the',
#  'shown up to the chamber',
#  'up to the chamber which',
#  'to the chamber which had',
#  'the chamber which had formerly',
#  'chamber which had formerly been',
#  'which had formerly been in',
#  'had formerly been in part',
#  'formerly been in part my',
#  'been in part my own',
#  'in part my own his',
#  'part my own his manner',
#  'my own his manner was',
#  'own his manner was not',
#  'his manner was not effusive',
#  'manner was not effusive it',
#  'was not effusive it seldom',
#  'not effusive it seldom was',
#  'effusive it seldom was but',
#  'it seldom was but he',
#  'seldom was but he was',
#  'was but he was glad',
#  'but he was glad i',
#  'he was glad i think',
#  'was glad i think to',
#  'glad i think to see',
#  'i think to see me',
#  'think to see me with',
#  'to see me with hardly',
#  'see me with hardly a',
#  'me with hardly a word',
#  'with hardly a word spoken',
#  'hardly a word spoken but',
#  'a word spoken but with',
#  'word spoken but with a',
#  'spoken but with a kindly',
#  'but with a kindly eye',
#  'with a kindly eye he',
#  'a kindly eye he waved',
#  'kindly eye he waved me',
#  'eye he waved me to',
#  'he waved me to an',
#  'waved me to an armchair',
#  'me to an armchair threw',
#  'to an armchair threw across',
#  'an armchair threw across his',
#  'armchair threw across his case',
#  'threw across his case of',
#  'across his case of cigars',
#  'his case of cigars and',
#  'case of cigars and indicated',
#  'of cigars and indicated a',
#  'cigars and indicated a spirit',
#  'and indicated a spirit case',
#  'indicated a spirit case and',
#  'a spirit case and a',
#  'spirit case and a gasogene',
#  'case and a gasogene in',
#  'and a gasogene in the',
#  'a gasogene in the corner',
#  'gasogene in the corner then',
#  'in the corner then he',
#  'the corner then he stood',
#  'corner then he stood before',
#  'then he stood before the',
#  'he stood before the fire',
#  'stood before the fire and',
#  'before the fire and looked',
#  'the fire and looked me',
#  'fire and looked me over',
#  'and looked me over in',
#  'looked me over in his',
#  'me over in his singular',
#  'over in his singular introspective',
#  'in his singular introspective fashion',
#  'his singular introspective fashion wedlock',
#  'singular introspective fashion wedlock suits',
#  'introspective fashion wedlock suits you',
#  'fashion wedlock suits you he',
#  'wedlock suits you he remarked',
#  'suits you he remarked i',
#  'you he remarked i think',
#  'he remarked i think watson',
#  'remarked i think watson that',
#  'i think watson that you',
#  ...]

# %% [markdown]
# # Probability Distribution

# %%
def get_prob_dist(data):
    
    prob_dist = []    
    a = np.array(data)
    pairs, counts = np.unique(a, return_counts = True)
    
    for i in range(len(pairs)):
        
        left_seq   = ' '.join(pairs[i].split(' ')[:len(pairs[i].split(' '))//2])
        right_seq  = ' '.join(pairs[i].split(' ')[len(pairs[i].split(' '))//2 + 1: ])
        middle_seq = pairs[i].split(' ')[len(pairs[i].split(' '))//2]
        
        prob_dist.append([pairs[i],left_seq, right_seq, middle_seq, counts[i]])
        
    return prob_dist
        
    
data = get_pairs(words,5)
prob_dist = get_prob_dist(data)

# %%
df = pd.DataFrame(prob_dist, columns = ['seq','left_seq','right_seq','output','freq'])
df.head()
# Out:
#                                 seq left_seq                right_seq output  \
# 0  0 05 grm novarsenbillon injected     0 05  novarsenbillon injected    grm
# 1                     0 25 u and is     0 25                   and is      u
# 2              0 45 grm given intra     0 45              given intra    grm
# 3                      0 5 to 2 per      0 5                    2 per     to
# 4                 0 6 grm all these      0 6                all these    grm
#
#    freq
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %% [markdown]
# # Getting the Predictions

# %%
def predict(word):
    left_seq = word.split('_')[0].strip()
    right_seq = word.split('_')[1].strip()
    
    df_ = df[df['left_seq'] == left_seq]
    df_ = df_[df_['right_seq'] == right_seq]
    return list(df_.sort_values(by = 'freq' , ascending = False).head()['output'].values)

# %%
predict('in the _ of the')
# Out:
# ['region', 'middle', 'case', 'vicinity', 'hands']

# %%
df.sort_values(by = 'freq')
# Out:
#                                                    seq           left_seq  \
# 0                     0 05 grm novarsenbillon injected               0 05
# 1089057                         zoology and so on just        zoology and
# 1089058                          zoology for in a frog        zoology for
# 1089059            zoology was not merely acknowledged        zoology was
# 1089060                       zu schwachen so kann man       zu schwachen
# ...                                                ...                ...
# 627289                        of the united states_ pp             of the
# 893586          the project gutenberg literary archive        the project
# 701067   project gutenberg literary archive foundation  project gutenberg
# 450975                            in the middle of the             in the
# 451986                            in the region of the             in the
#
#                        right_seq     output  freq
# 0        novarsenbillon injected        grm     1
# 1089057                  on just         so     1
# 1089058                   a frog         in     1
# 1089059      merely acknowledged        not     1
# 1089060                 kann man         so     1
# ...                          ...        ...   ...
# 627289                states_ pp     united    31
# 893586          literary archive  gutenberg    32
# 701067        archive foundation   literary    36
# 450975                    of the     middle    38
# 451986                    of the     region    38
#
# [1089074 rows x 5 columns]
